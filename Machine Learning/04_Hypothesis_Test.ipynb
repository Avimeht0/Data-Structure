# %% [markdown]
# ### 📌 Hypothesis Testing – Short Notes
#
# #### 🔸 What is it?
#
# A way to test if your **assumption about data is true** or just happened by **chance**.
#
# ---
#
# ### 🔹 Key Terms:
#
# | Term                            | Meaning                                    |
# | ------------------------------- | ------------------------------------------ |
# | **H₀ (Null Hypothesis)**        | No effect or difference                    |
# | **H₁ (Alternative Hypothesis)** | There is an effect or difference           |
# | **p-value**                     | Probability that results are due to chance |
# | **α (alpha)**                   | Significance level (commonly 0.05)         |
#
# ---
#
# ### 🔸 Steps:
#
# 1. **Set Hypotheses**
#    H₀: No difference
#    H₁: There is a difference
#
# 2. **Choose α (e.g., 0.05)**
#
# 3. **Collect Data**
#
# 4. **Calculate p-value**
#
# 5. **Make Decision**
#
#    * If **p-value < α** → Reject H₀
#    * If **p-value ≥ α** → Do not reject H₀
#
# ---
#
# ### 🔸 Example:
#
# **You test two website designs (A and B):**
#
# * A: 20 clicks out of 100 users
# * B: 30 clicks out of 100 users
#
# **H₀:** Both designs have same click rate
# **H₁:** Design B has higher click rate
#
# → You calculate p-value (e.g., 0.03)
# → 0.03 < 0.05 → ✅ **Reject H₀** → Design B is better
#
# ---
#
# ### 🔸 In ML:
#
# Used to:
#
# * Compare models
# * Test feature importance
# * Validate assumptions
